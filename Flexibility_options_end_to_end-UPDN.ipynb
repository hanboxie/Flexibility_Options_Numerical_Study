# %% [markdown]
# Load packages

# %%
import pyomo.environ as pyo
import pandas as pd
import numpy as np
from datetime import date
import ast

# %% [markdown]
# Define DA model with Flexibility Options

# %%
DAFOmodel = pyo.AbstractModel()

#Sets
DAFOmodel.S = pyo.RangeSet(1, 5) #Set of scenarios
DAFOmodel.G = pyo.RangeSet(1, 5) #Set of generators
DAFOmodel.R = pyo.RangeSet(1, 4) #Set of tiers

#Parameters
DAFOmodel.VC = pyo.Param(DAFOmodel.G) #Variable cost
DAFOmodel.VCUP = pyo.Param(DAFOmodel.G) #Variable cost
DAFOmodel.VCDN = pyo.Param(DAFOmodel.G) #Variable cost
DAFOmodel.CAP = pyo.Param(DAFOmodel.G) #Capacity
DAFOmodel.REDA=pyo.Param(within=pyo.NonNegativeIntegers) #Maximum DA RE
DAFOmodel.DEMAND=pyo.Param(within=pyo.NonNegativeIntegers) #Electricty demand
DAFOmodel.D1=pyo.Param(within=pyo.NonNegativeIntegers) #linear cost coefficient for demand slack variable
DAFOmodel.D2=pyo.Param(within=pyo.NonNegativeIntegers) #quadratic cost coefficient for demand slack variable

#Parameters specific to the FO
DAFOmodel.RR= pyo.Param(DAFOmodel.G) #Ramp rate
DAFOmodel.RE = pyo.Param(DAFOmodel.S) #Renewable generation at each scenario [FO buyer]
DAFOmodel.PEN=pyo.Param(within=pyo.NonNegativeIntegers) #Penalty for inadequate flexibility up [FO buyer]
DAFOmodel.PENDN=pyo.Param(within=pyo.NonNegativeIntegers) #Penalty for inadequate flexibility down [FO buyer]
DAFOmodel.smallM=pyo.Param(within=pyo.NonNegativeReals) #Parameter that helps choose among alternative optima
DAFOmodel.probTU=pyo.Param(DAFOmodel.R) #probability of exercise FO up
DAFOmodel.probTD=pyo.Param(DAFOmodel.R) #probability of exercise FO dn

# Variables
DAFOmodel.d = pyo.Var(domain=pyo.NonNegativeReals) #slack for demand that makes demand elastic and helps us with degeneracy
DAFOmodel.xDA=pyo.Var(DAFOmodel.G, domain=pyo.NonNegativeReals) #DA energy schedule for generators
DAFOmodel.rgDA=pyo.Var(domain=pyo.NonNegativeReals) #DA energy schedule for renewables
DAFOmodel.du= pyo.Var(DAFOmodel.S)

#Variables [FO]
DAFOmodel.hsu  = pyo.Var(DAFOmodel.R, DAFOmodel.G, domain=pyo.NonNegativeReals) #supply FO up
DAFOmodel.hsd  = pyo.Var(DAFOmodel.R, DAFOmodel.G, domain=pyo.NonNegativeReals) #supply FO down
DAFOmodel.hdu  = pyo.Var(DAFOmodel.R, domain=pyo.NonNegativeReals) #demand FO up
DAFOmodel.hdd  = pyo.Var(DAFOmodel.R, domain=pyo.NonNegativeReals)  #demand FO down
DAFOmodel.sdu  = pyo.Var(DAFOmodel.R, domain=pyo.NonNegativeReals)  #Self-supply FO up [FO buyer]
DAFOmodel.sdd  = pyo.Var(DAFOmodel.R, domain=pyo.NonNegativeReals) #Self-supply FO down [FO buyer]
DAFOmodel.y    = pyo.Var(DAFOmodel.S, domain=pyo.NonNegativeReals) #Auxiliary variable



#Define objective function
def obj_expression(m):
    return sum(m.VC[g]*m.xDA[g] for g in m.G)+sum(m.probTU[r]*m.VCUP[g]*m.hsu[r,g] for g in m.G for r in m.R)\
+sum(m.probTU[r]*m.PEN*m.sdu[r]  for r in m.R)-sum(m.probTD[r]*(m.VCDN[g])*m.hsd[r,g] for g in m.G for r in m.R)\
-sum(m.probTD[r]*m.PENDN*m.sdd[r] for r in m.R)+sum(m.y[s] for s in m.S)*m.smallM \
+sum(0.2*m.D1*(m.d+m.du[s])  for s in m.S) +0.2*m.D2*sum((m.d+m.du[s])*(m.d+m.du[s]) for s in m.S  )\
###### create symmetry with demand curve in real-time, #+ m.D2 *m.d*m.d

DAFOmodel.OBJ = pyo.Objective(rule=obj_expression)

#Define constraints - Numbering of constraints follows paper
def DA_energy_balance(model):
    return sum(model.xDA[g] for g in model.G)+ model.rgDA+model.d == model.DEMAND
DAFOmodel.Con3 = pyo.Constraint(expr=DA_energy_balance) 

def DA_flexup_balance(model,r):
    return sum(model.hsu[r,g] for g in model.G) == model.hdu[r]
DAFOmodel.Con4UP = pyo.Constraint(DAFOmodel.R, rule=DA_flexup_balance)

def DA_flexdn_balance(model,r):
    return sum(model.hsd[r,g] for g in model.G) == model.hdd[r]
DAFOmodel.Con4DN = pyo.Constraint(DAFOmodel.R, rule=DA_flexdn_balance)

def DA_flex_demand(model,s):
    return -model.du[s]+sum(model.hdd[r]+model.sdd[r] for r in model.R if r<=s-1 )-sum(model.hdu[r]+model.sdu[r] for r in model.R if r>=s )==model.RE[s]-model.rgDA
DAFOmodel.Con6 = pyo.Constraint(DAFOmodel.S, rule=DA_flex_demand)

def DA_flex_demand_bound(model,s):
    return sum(model.hdd[r]+model.sdd[r] for r in model.R if r<=s-1 )+sum(model.hdu[r]+model.sdu[r] for r in model.R if r>=s )<=model.y[s]
DAFOmodel.Con7 = pyo.Constraint(DAFOmodel.S, rule=DA_flex_demand_bound)

def Y2(model,s):
    return model.y[s]>=model.rgDA-model.RE[s]
DAFOmodel.Con8  = pyo.Constraint(DAFOmodel.S, rule=Y2)  

def Y1(model,s):
    return model.y[s]>=model.RE[s]-model.rgDA
DAFOmodel.Con9 = pyo.Constraint(DAFOmodel.S, rule=Y1)  
    
def RRUP(model,g):
    return sum(model.hsu[r,g] for r in model.R)<=model.RR[g]
DAFOmodel.Con10up = pyo.Constraint(DAFOmodel.S, rule=RRUP)  

def RRDN(model,g):
    return sum(model.hsd[r,g] for r in model.R)<=model.RR[g]
DAFOmodel.Con10dn = pyo.Constraint(DAFOmodel.S, rule=RRDN) 

def DA_capacity_cons(model, g):
    return model.xDA[g] +sum(model.hsu[r,g] for r in model.R)<= model.CAP[g]
DAFOmodel.Con11 = pyo.Constraint(DAFOmodel.G, rule=DA_capacity_cons)

def DA_down_cons(model, g):
    return  sum(model.hsd[r,g] for r in model.R)<= model.xDA[g]
DAFOmodel.Con12= pyo.Constraint(DAFOmodel.G, rule=DA_down_cons)

#Record duals
DAFOmodel.dual = pyo.Suffix(direction=pyo.Suffix.IMPORT)

# %% [markdown]
# Storage DA model

# %%
# # Add to DAFOmodel parameters
# DAFOmodel.E_MAX = pyo.Param(DAFOmodel.G)  # Max energy capacity 
# DAFOmodel.P_MAX = pyo.Param(DAFOmodel.G)  # Max power capacity
# DAFOmodel.ETA_CH = pyo.Param(DAFOmodel.G) # Charging efficiency 
# DAFOmodel.ETA_DCH = pyo.Param(DAFOmodel.G) # Discharging efficiency
# DAFOmodel.E0 = pyo.Param(DAFOmodel.G)     # Initial state of charge

# # Add storage variables
# DAFOmodel.e = pyo.Var(DAFOmodel.G, domain=pyo.NonNegativeReals) # Energy level
# DAFOmodel.p_ch = pyo.Var(DAFOmodel.G, domain=pyo.NonNegativeReals) # Charging power
# DAFOmodel.p_dch = pyo.Var(DAFOmodel.G, domain=pyo.NonNegativeReals) # Discharging power

# def storage_balance(model, g):
#     return model.e[g] == model.E0[g] + \
#            model.ETA_CH[g] * model.p_ch[g] - \
#            (1/model.ETA_DCH[g]) * model.p_dch[g]
# DAFOmodel.storage_balance = pyo.Constraint(DAFOmodel.G, rule=storage_balance)

# def storage_capacity(model, g):
#     return model.e[g] <= model.E_MAX[g]
# DAFOmodel.storage_capacity = pyo.Constraint(DAFOmodel.G, rule=storage_capacity)

# def power_limits(model, g):
#     return model.p_ch[g] + model.p_dch[g] <= model.P_MAX[g]
# DAFOmodel.power_limits = pyo.Constraint(DAFOmodel.G, rule=power_limits)

# %% [markdown]
# Storage RT model

# %%
RTsim = pyo.AbstractModel()

# %%
# # Add to RTsim parameters - match DA model parameters
# RTsim.E_MAX = pyo.Param(RTsim.G)
# RTsim.P_MAX = pyo.Param(RTsim.G) 
# RTsim.ETA_CH = pyo.Param(RTsim.G)
# RTsim.ETA_DCH = pyo.Param(RTsim.G)
# RTsim.E0 = pyo.Param(RTsim.G)

# # Add RT storage variables per scenario
# RTsim.e = pyo.Var(RTsim.S, RTsim.G, domain=pyo.NonNegativeReals)
# RTsim.p_ch = pyo.Var(RTsim.S, RTsim.G, domain=pyo.NonNegativeReals)
# RTsim.p_dch = pyo.Var(RTsim.S, RTsim.G, domain=pyo.NonNegativeReals)

# # Storage balance constraint per scenario
# def RT_storage_balance(model, s, g):
#     return model.e[s,g] == model.E0[g] + \
#            model.ETA_CH[g] * model.p_ch[s,g] - \
#            (1/model.ETA_DCH[g]) * model.p_dch[s,g]
# RTsim.storage_balance = pyo.Constraint(RTsim.S, RTsim.G, rule=RT_storage_balance)

# # Storage capacity constraint
# def RT_storage_capacity(model, s, g):
#     return model.e[s,g] <= model.E_MAX[g]
# RTsim.storage_capacity = pyo.Constraint(RTsim.S, RTsim.G, rule=RT_storage_capacity)

# # Power limits
# def RT_power_limits(model, s, g):
#     return model.p_ch[s,g] + model.p_dch[s,g] <= model.P_MAX[g]
# RTsim.power_limits = pyo.Constraint(RTsim.S, RTsim.G, rule=RT_power_limits)

# # Update RT energy balance
# def RT_energy_balance(model,s):
#     return sum(model.xup[s,g] - model.xdn[s,g] + \
#               model.p_dch[s,g] - model.p_ch[s,g] for g in model.G) + \
#            model.rgup[s] - model.rgdn[s] + model.d[s] == 0

# %% [markdown]
# Stochastic Program that is used to simulate the impact of DA decisions on RT

# %%
#Sets
RTsim.S = pyo.RangeSet(1, 5)
RTsim.G = pyo.RangeSet(1, 5)

#Parameters
RTsim.VC = pyo.Param(RTsim.G)
RTsim.VCUP = pyo.Param(RTsim.G)
RTsim.VCDN = pyo.Param(RTsim.G)
RTsim.CAP = pyo.Param(RTsim.G)
RTsim.RR= pyo.Param(RTsim.G)

RTsim.prob=pyo.Param(RTsim.S)
RTsim.RE = pyo.Param(RTsim.S)
RTsim.DEMAND=pyo.Param(within=pyo.NonNegativeIntegers)
RTsim.D1=pyo.Param(within=pyo.NonNegativeIntegers)
RTsim.D2=pyo.Param(within=pyo.NonNegativeIntegers)
RTsim.xDA=pyo.Param(RTsim.G, domain=pyo.NonNegativeReals)
RTsim.REDA=pyo.Param( domain=pyo.NonNegativeReals)
RTsim.PEN=pyo.Param(within=pyo.NonNegativeIntegers)
RTsim.PENDN=pyo.Param()
RTsim.DAdr=pyo.Param()

# Variables
RTsim.xup = pyo.Var(RTsim.S, RTsim.G, domain=pyo.NonNegativeReals)
RTsim.xdn = pyo.Var(RTsim.S, RTsim.G, domain=pyo.NonNegativeReals)
RTsim.d= pyo.Var(RTsim.S)
RTsim.rgup = pyo.Var(RTsim.S, domain=pyo.NonNegativeReals)
RTsim.rgdn = pyo.Var(RTsim.S, domain=pyo.NonNegativeReals)
RTsim.sdup = pyo.Var(RTsim.S, domain=pyo.NonNegativeReals)
RTsim.sddn = pyo.Var(RTsim.S, domain=pyo.NonNegativeReals)

#Objective
def obj_expression(m):
    return sum(m.prob[s]*(m.VCUP[g]*m.xup[s,g]-m.VCDN[g]*m.xdn[s,g]) for g in m.G for s in m.S)+m.PENDN*sum(m.prob[s]*m.sdup[s] for s in m.S)+m.PEN*sum(m.prob[s]*m.sddn[s] for s in m.S)\
+sum(m.prob[s]*(m.D1*(m.DAdr+m.d[s])+m.D2*(m.DAdr+m.d[s])*(m.DAdr+m.d[s])) for s in m.S)\
-sum(m.prob[s]*(m.D1*(m.DAdr)+m.D2*(m.DAdr)*(m.DAdr)) for s in m.S)
RTsim.OBJ = pyo.Objective(rule=obj_expression)

#Constraints
def RT_energy_balance(model,s):
    return sum(model.xup[s,g]-model.xdn[s,g] for g in model.G)+ model.rgup[s]-model.rgdn[s] +model.d[s]== 0

def RT_RE_availability(model,s):
    return model.rgup[s]-model.rgdn[s]+model.sdup[s]-model.sddn[s] ==model.RE[s]-model.REDA 

def RT_ramp_up(model,s,g):
    return model.xup[s,g] <=model.RR[g]

def RT_ramp_dn(model,s,g):
    return model.xdn[s,g] <= model.RR[g]
def RT_capacity_cons(model,s, g):
    return model.xDA[g]+model.xup[s,g] <= model.CAP[g]

def RT_capacity_min(model,s, g):
    return model.xDA[g]-model.xdn[s,g] >=0

# Numbering of constraints follows the RT problem
RTsim.Con3 = pyo.Constraint(RTsim.S, rule=RT_energy_balance)
RTsim.Con4 = pyo.Constraint(RTsim.S, rule= RT_RE_availability)
RTsim.Con5up = pyo.Constraint(RTsim.S,RTsim.G, rule=RT_ramp_up)
RTsim.Con5dn = pyo.Constraint(RTsim.S, RTsim.G,rule=RT_ramp_dn)
RTsim.Con6 = pyo.Constraint(RTsim.S,RTsim.G, rule=RT_capacity_cons)
RTsim.Con7 = pyo.Constraint(RTsim.S,RTsim.G, rule=RT_capacity_min)

#Record duals
RTsim.dual = pyo.Suffix(direction=pyo.Suffix.IMPORT)

# %% [markdown]
# Use CPLEX to solve the problem [quadratic objective function due to elastic demand]

# %%
opt = pyo.SolverFactory('cplex',executable='C:/Program Files/IBM/ILOG/CPLEX_Studio_Community2212/cplex/bin/x64_win64/cplex')

# opt = pyo.SolverFactory('ipopt')

# opt.options['max_iter'] = 10000
# opt.options['tol'] = 1e-6
# opt.options['acceptable_tol'] = 1e-5
# opt.options['linear_solver'] = 'ma57'  # or 'mumps' if ma57 is not available
# opt.options['hessian_approximation'] = 'limited-memory'

# %% [markdown]
# Read input data from excel and record outputs in indvidual excel files

# %%
import json

def solve_with_handling(model, solver):
    try:
        result = solver.solve(model, tee=True)
        if (result.solver.status == pyo.SolverStatus.ok and 
            result.solver.termination_condition == pyo.TerminationCondition.optimal):
            return True
        else:
            print(f"Solver status: {result.solver.status}")
            print(f"Termination condition: {result.solver.termination_condition}")
            return False
    except Exception as e:
        print(f"Error solving model: {str(e)}")
        return False


input_data=pd.read_csv('Input_files/FO_input_sectionV.csv',index_col=0)
Summary_cost=pd.DataFrame() # system cost
Summary_price_convergence=pd.DataFrame() # Price convergence between DA and RT markets
Summary_premium_convergence_up=pd.DataFrame() # FO premium convergence for upward/downward flexibility
Summary_premium_convergence_down=pd.DataFrame() # Tracks reliability of revenue streams (frequency of positive margins)
Summary_margin_intermittency=pd.DataFrame() # Costs related to unmet demand
Summary_costD=pd.DataFrame() # Costs related to generation curtailment
Summary_costCURT=pd.DataFrame()
for l in input_data.columns:
        dataDA=input_data[l].to_dict()
        for k in range(0,len(input_data[l])):
            # Handle potential np.float64(nan) values that cause ast.literal_eval to fail
            try:
                value = input_data[l][input_data.index[k]]
                if pd.isna(value):
                    dataDA[input_data.index[k]] = float('nan')
                else:
                    dataDA[input_data.index[k]] = ast.literal_eval(value)
            except ValueError as e:
                if "malformed node or string" in str(e):
                    # If it's a numpy float64 nan, convert to Python float nan
                    dataDA[input_data.index[k]] = float('nan')
                else:
                    raise e
        dataDA = {None: dataDA}
        # print(json.dumps(dataDA, indent=4, sort_keys=True))
        i = DAFOmodel.create_instance(dataDA)
        opt.solve(i, tee=True)
        # if not solve_with_handling(i, opt):
        #     print("Failed to solve DA model")
        #     continue  # Skip to next iteration of the loop
        #Values to pass from DA to RT module
        # Energy=pd.DataFrame()
        # E_grid_data = {(G): v.value for (G), v in i.xDA.items()}
        # Energy['en']= pd.DataFrame.from_dict(E_grid_data, orient="index", columns=["en"])
        # temp=i.rgDA.value
        # Total=pd.DataFrame()
        # Total.at['cost','DA']=sum(np.multiply(np.array([i.VC[k] for k in i.G]),np.array([i.xDA[g].value for g in i.G])))
        # Total.at['price','DA']=i.dual[i.Con3]
        # E_grid_data = {(R): v.value for (R), v in i.hdu.items()}
        # demand = pd.DataFrame.from_dict(E_grid_data, orient="index", columns=["hdu"])
        # E_grid_data = {(R): v.value for (R), v in i.hdd.items()}
        # demand ['hdd']= pd.DataFrame.from_dict(E_grid_data, orient="index", columns=["hdd"])
        # E_grid_data = {(R,G): v.value for (R,G), v in i.hsu.items()}
        # df = pd.DataFrame.from_dict(E_grid_data, orient="index", columns=["hsu"])
        # E_grid_data = {(R,G): v.value for (R,G), v in i.hsd.items()}
        # df ['hsd']= pd.DataFrame.from_dict(E_grid_data, orient="index", columns=["hsd"])
        # df['R']=[df.index[i][0] for i in range(0,len(df))]
        # df['G']=[df.index[i][1] for i in range(0,len(df))]
        # Prices=pd.DataFrame()
        # Prices['up']=[i.dual[i.Con4UP[r]] for r in i.R]
        # Prices['down']=[i.dual[i.Con4DN[r]] for r in i.R]
        # Gross_margins=pd.DataFrame()
        # Gross_margins["en"]=np.multiply(i.dual[i.Con3]-np.array([i.VC[k] for k in i.G]), Energy['en'])
        # #Gross_margins.at[0,"en"]=i.rgDA.value*i.dual[i.Con3]
        # for tier in range(1,5):
        #     temp2=np.multiply(df["hsu"].loc[df["R"]==tier].reset_index(drop=True), Prices.at[tier-1,"up"]-np.multiply(np.array([i.VCUP[k] for k in i.G]),i.probTU[tier]))
        #     temp2.index=range(1,6)
        #     Gross_margins["up"+str(tier)]=temp2
        #     temp2=np.multiply(df["hsd"].loc[df["R"]==tier].reset_index(drop=True), Prices.at[tier-1,"down"]+np.multiply(np.array([i.VCDN[k] for k in i.G]),i.probTD[tier]))
        #     temp2.index=range(1,6)
        #     Gross_margins["down"+str(tier)]=temp2
            
        # dataRT = {None:{
        #     'RE': dataDA[None]["RE"],
        #     'CAP': dataDA[None]["CAP"],
        #     'VC': dataDA[None]["VC"],
        #     'VCUP': dataDA[None]["VCUP"],
        #     'VCDN': dataDA[None]["VCDN"],
        #     'DEMAND': dataDA[None]["DEMAND"],
        #     'D1': dataDA[None]["D1"],
        #     'D2': dataDA[None]["D2"],
        #     'prob':{1: 0.2, 2:0.2, 3:0.2, 4:0.2, 5:0.2},
        #       'RR': dataDA[None]["RR"],
        #     'xDA':Energy['en'],
        #      'PEN':dataDA[None]["PEN"],
        #      'PENDN':dataDA[None]["PENDN"],
        #      'REDA':{None: temp},
        #      'DAdr':{None: i.d.value}
        #     }}
        # iRT = RTsim.create_instance(dataRT)
        # opt.solve(iRT)
        # RTmargins=pd.DataFrame()
        # for s in iRT.S:  
        #     RTmargins[s]=(np.multiply(iRT.dual[iRT.Con3[s]]-iRT.prob[s]*np.array([iRT.VC[k] for k in iRT.G]),np.array([iRT.xup[s,k].value-iRT.xdn[s,k].value  for k in i.G])))
        # RTmargins.index=range(1,len(RTmargins)+1)
        # RTpayoffs=pd.DataFrame()
        # for s in iRT.S: 
        #     if s<5:
        #         RTpayoffs["UP"+str(s)]=-(iRT.dual[iRT.Con3[s]]*df[["hsu","G"]].loc[df["R"]>=s].groupby("G").sum().values.transpose()-np.multiply(iRT.prob[s]*np.array([iRT.VCUP[k] for k in iRT.G]),df[["hsu","G"]].loc[df["R"]>=s].groupby("G").sum().values.transpose()))[0]
        #     if s>1:
        #          RTpayoffs["DN"+str(s)]=(iRT.dual[iRT.Con3[s]]*df[["hsd","G"]].loc[df["R"]<s].groupby("G").sum().values.transpose()-np.multiply(iRT.prob[s]*np.array([iRT.VCDN[k] for k in iRT.G]),df[["hsd","G"]].loc[df["R"]<s].groupby("G").sum().values.transpose()))[0]
        # RTpayoffs.index=range(1,len(RTpayoffs)+1)
        # for s in i.S:
        #    Total.at['cost',s]=iRT.prob[s]*(sum(np.multiply(np.array([i.VCUP[k] for k in i.G]),np.array([iRT.xup[s,g].value for g in iRT.G])))+sum(np.multiply(np.array([i.VCDN[k] for k in i.G]),np.array([-iRT.xdn[s,g].value for g in iRT.G]))))
        #    Total.at['price',s]=iRT.dual[iRT.Con3[s]]
        #    Total.at['unmet_demand',s]=iRT.prob[s]*(iRT.D1*iRT.d[s].value+iRT.D2*iRT.d[s].value*iRT.d[s].value)
        #    Total.at['curtail cost',s]=iRT.prob[s]*(iRT.PENDN*iRT.sdup[s].value)
        # price_convergence=Total.at['price','DA']-Total[Total.columns[1:]].loc['price'].sum()
        # premium_convergence=pd.DataFrame()
        # premiums=Gross_margins[Gross_margins.columns[Gross_margins.columns.str.startswith('up')]].sum().sum()+Gross_margins[Gross_margins.columns[Gross_margins.columns.str.startswith('down')]].sum().sum()
        # premium_convergence['UP']=Gross_margins[Gross_margins.columns[Gross_margins.columns.str.startswith('up')]].sum(axis=1)+RTpayoffs[RTpayoffs.columns[RTpayoffs.columns.str.startswith('UP')]].sum(axis=1)
        # premium_convergence['DN']=Gross_margins[Gross_margins.columns[Gross_margins.columns.str.startswith('down')]].sum(axis=1)+RTpayoffs[RTpayoffs.columns[RTpayoffs.columns.str.startswith('DN')]].sum(axis=1)
        # premium_convergence.index.name='Generator'
        # premium_convergence.index=premium_convergence.index+1
        # Total_margin=pd.DataFrame()
        # for k in range(1,6):
        #      Total_margin[k]=iRT.prob[k]*Gross_margins.sum(axis=1)+RTmargins[k]+RTpayoffs[RTpayoffs.columns[RTpayoffs.columns.str.endswith(str(k))]].sum(axis=1)
        #      Total_margin.at['RE',k]=(iRT.dual[iRT.Con3[k]]*(iRT.rgup[k].value-iRT.rgdn[k].value)) +iRT.prob[k]*temp*i.dual[i.Con3]-iRT.prob[k]*premiums
        #      if k>1:
        #         Total_margin.at['RE',k]=Total_margin.at['RE',k]-RTpayoffs["DN"+str(k)].sum()
        #      if k<5:
        #         Total_margin.at['RE',k]=Total_margin.at['RE',k]-RTpayoffs["UP"+str(k)].sum()
        #      Total_margin.at['DR',k]=iRT.dual[iRT.Con3[k]]*iRT.d[k].value+iRT.prob[k]*i.d.value*i.dual[i.Con3] -iRT.prob[k]*(i.D1*(iRT.d[k].value+i.d.value))-iRT.prob[k]*(i.D2*(iRT.d[k].value+i.d.value)*(iRT.d[k].value+i.d.value))
        # writer = pd.ExcelWriter('Test_output_files/Results_SectionV/FO_EXP_'+l+"_v"+date.today().strftime("%Y_%m_%d")+'revision.xlsx')      
        # round(premium_convergence,2).to_excel(writer,'Premium_convergence')
        # round(Total,2).to_excel(writer,'System_metrics')
        # round(RTmargins,2).to_excel(writer,'RTmargins')
        # round(RTpayoffs,2).to_excel(writer,'RTpayoffs')
        # round(Gross_margins,2).to_excel(writer,'Grossmargins')
        # round(df,2).to_excel(writer,'FO_supply_AWARDS')
        # round(demand,2).to_excel(writer,'FO_demand_AWARDS')
        # round(Energy,2).to_excel(writer,'DA_energy')
        # round(Total_margin,2).to_excel(writer,'Totalmargins')
        # round(Prices,2).to_excel(writer,'Prices')
        # pd.DataFrame(dataDA).to_excel(writer,'input_DA')
        # pd.DataFrame(dataRT).to_excel(writer,'input_RT')
        # writer.close()
        # Summary_cost[l]=Total.loc['cost'].transpose()
        # Summary_costD[l]=Total.loc['unmet_demand'].transpose()
        # Summary_price_convergence[l]=Total.loc['price'].transpose()
        # Summary_premium_convergence_up[l]=premium_convergence['UP']
        # Summary_premium_convergence_down[l]=premium_convergence['DN']
        # #Summary_margin_intermittency[l]=Total_margin.apply(lambda row: sum(row>0.01),axis=1)
        # Summary_costCURT[l]=Total.loc['curtail cost'].transpose()
# Out:
# Welcome to IBM(R) ILOG(R) CPLEX(R) Interactive Optimizer Community Edition 22.1.2.0
#   with Simplex, Mixed Integer & Barrier Optimizers
# 5725-A06 5725-A29 5724-Y48 5724-Y49 5724-Y54 5724-Y55 5655-Y21
# Copyright IBM Corp. 1988, 2024.  All Rights Reserved.
#
# Type 'help' for a list of available commands.
# Type 'help' followed by a command name for more
# information on commands.
#
# CPLEX> Logfile 'cplex.log' closed.
# Logfile 'C:\Users\hanbo\AppData\Local\Temp\tmpljnk8w0i.cplex.log' open.
# CPLEX> Problem 'C:\Users\hanbo\AppData\Local\Temp\tmpq74nkwo_.pyomo.lp' read.
# Read time = 0.00 sec. (0.01 ticks)
# CPLEX> Problem name         : C:\Users\hanbo\AppData\Local\Temp\tmpq74nkwo_.pyomo.lp
# Objective sense      : Minimize
# Variables            :      73  [Nneg: 68,  Free: 5,  Qobj: 6]
# Objective nonzeros   :      60
# Objective Q nonzeros :      16
# Linear constraints   :      49  [Less: 35,  Equal: 14]
#   Nonzeros           :     260
#   RHS nonzeros       :      31
#
# Variables            : Min LB: 0.000000         Max UB: all infinite
# Objective nonzeros   : Min   : 0.01000000       Max   : 1600.000
# Objective Q nonzeros : Min   : 220.0000         Max   : 1100.000
# Linear constraints   :
#   Nonzeros           : Min   : 1.000000         Max   : 1.000000
#   RHS nonzeros       : Min   : 10.00000         Max   : 200.0000
# CPLEX> Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# Number of nonzeros in lower triangle of Q = 5
# Using Approximate Minimum Degree ordering
# Total time for automatic ordering = 0.00 sec. (0.00 ticks)
# Summary statistics for factor of Q:
#   Rows in Factor            = 6
#   Integer space required    = 6
#   Total non-zeros in factor = 21
#   Total FP ops to factor    = 91
# Tried aggregator 1 time.
# QP Presolve eliminated 1 rows and 1 columns.
# QP Presolve added 0 rows and 6 columns.
# Aggregator did 9 substitutions.
# Reduced QP has 45 rows, 69 columns, and 289 nonzeros.
# Reduced QP objective Q matrix has 5 nonzeros.
# Presolve time = 0.00 sec. (0.05 ticks)
# Parallel mode: using up to 32 threads for barrier.
# Number of nonzeros in lower triangle of A*A' = 335
# Using Approximate Minimum Degree ordering
# Total time for automatic ordering = 0.00 sec. (0.02 ticks)
# Summary statistics for Cholesky factor:
#   Threads                   = 32
#   Rows in Factor            = 45
#   Integer space required    = 126
#   Total non-zeros in factor = 570
#   Total FP ops to factor    = 8970
#  Itn      Primal Obj        Dual Obj  Prim Inf Upper Inf  Dual Inf
#    0   1.2537675e+05  -7.0751718e+03  6.27e+03  0.00e+00  9.89e+04
#    1   3.1457735e+04  -1.0117970e+05  1.45e+03  0.00e+00  2.28e+04
#    2   6.0854250e+03  -5.5046521e+04  1.80e+02  0.00e+00  2.85e+03
#    3   2.7073031e+03  -1.7070709e+04  1.54e+01  0.00e+00  2.42e+02
#    4   1.7729769e+03  -1.0773472e+03  2.08e+00  0.00e+00  3.28e+01
#    5   1.3390820e+03   4.3972079e+02  3.69e-01  0.00e+00  5.83e+00
#    6   1.2090578e+03   8.1694483e+02  1.35e-01  0.00e+00  2.12e+00
#    7   1.1229598e+03   9.7773955e+02  4.11e-02  0.00e+00  6.49e-01
#    8   1.0684838e+03   1.0429886e+03  2.38e-03  0.00e+00  3.75e-02
#    9   1.0578976e+03   1.0528550e+03  4.48e-04  0.00e+00  7.07e-03
#   10   1.0562487e+03   1.0548663e+03  1.19e-04  0.00e+00  1.88e-03
#   11   1.0554470e+03   1.0552592e+03  1.51e-05  0.00e+00  2.38e-04
#   12   1.0553306e+03   1.0553176e+03  9.03e-07  0.00e+00  1.43e-05
#   13   1.0553248e+03   1.0553213e+03  2.31e-07  0.00e+00  3.62e-06
#   14   1.0553236e+03   1.0553221e+03  9.93e-08  0.00e+00  1.56e-06
#   15   1.0553231e+03   1.0553225e+03  5.72e-08  0.00e+00  6.54e-07
#   16   1.0553229e+03   1.0553226e+03  2.54e-08  0.00e+00  2.74e-07
#   17   1.0553227e+03   1.0553227e+03  2.10e-08  0.00e+00  4.75e-09
# Barrier time = 0.02 sec. (0.44 ticks)
#
# Total time on 32 threads = 0.02 sec. (0.44 ticks)
#
# Barrier - Optimal:  Objective =  1.0553227319e+03
# Solution time =    0.03 sec.  Iterations = 17
# Deterministic time = 0.44 ticks  (14.07 ticks/sec)
#
# CPLEX> Solution written to file 'C:\Users\hanbo\AppData\Local\Temp\tmpyf6361xn.cplex.sol'.
# CPLEX>
# Welcome to IBM(R) ILOG(R) CPLEX(R) Interactive Optimizer Community Edition 22.1.2.0
#   with Simplex, Mixed Integer & Barrier Optimizers
# 5725-A06 5725-A29 5724-Y48 5724-Y49 5724-Y54 5724-Y55 5655-Y21
# Copyright IBM Corp. 1988, 2024.  All Rights Reserved.
#
# Type 'help' for a list of available commands.
# Type 'help' followed by a command name for more
# information on commands.
#
# CPLEX> Logfile 'cplex.log' closed.
# Logfile 'C:\Users\hanbo\AppData\Local\Temp\tmptq4dp13m.cplex.log' open.
# CPLEX> Problem 'C:\Users\hanbo\AppData\Local\Temp\tmp1ndhuukg.pyomo.lp' read.
# Read time = 0.00 sec. (0.01 ticks)
# CPLEX> Problem name         : C:\Users\hanbo\AppData\Local\Temp\tmp1ndhuukg.pyomo.lp
# Objective sense      : Minimize
# Variables            :      73  [Nneg: 68,  Free: 5,  Qobj: 6]
# Objective nonzeros   :      60
# Objective Q nonzeros :      16
# Linear constraints   :      49  [Less: 35,  Equal: 14]
#   Nonzeros           :     260
#   RHS nonzeros       :      31
#
# Variables            : Min LB: 0.000000         Max UB: all infinite
# Objective nonzeros   : Min   : 0.01000000       Max   : 1600.000
# Objective Q nonzeros : Min   : 220.0000         Max   : 1100.000
# Linear constraints   :
#   Nonzeros           : Min   : 1.000000         Max   : 1.000000
#   RHS nonzeros       : Min   : 6.000000         Max   : 200.0000
# CPLEX> Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# Number of nonzeros in lower triangle of Q = 5
# Using Approximate Minimum Degree ordering
# Total time for automatic ordering = 0.02 sec. (0.00 ticks)
# Summary statistics for factor of Q:
#   Rows in Factor            = 6
#   Integer space required    = 6
#   Total non-zeros in factor = 21
#   Total FP ops to factor    = 91
# Tried aggregator 1 time.
# QP Presolve eliminated 1 rows and 1 columns.
# QP Presolve added 0 rows and 6 columns.
# Aggregator did 9 substitutions.
# Reduced QP has 45 rows, 69 columns, and 289 nonzeros.
# Reduced QP objective Q matrix has 5 nonzeros.
# Presolve time = 0.02 sec. (0.05 ticks)
# Parallel mode: using up to 32 threads for barrier.
# Number of nonzeros in lower triangle of A*A' = 335
# Using Approximate Minimum Degree ordering
# Total time for automatic ordering = 0.00 sec. (0.02 ticks)
# Summary statistics for Cholesky factor:
#   Threads                   = 32
#   Rows in Factor            = 45
#   Integer space required    = 126
#   Total non-zeros in factor = 570
#   Total FP ops to factor    = 8970
#  Itn      Primal Obj        Dual Obj  Prim Inf Upper Inf  Dual Inf
#    0   1.3283190e+05  -1.2454379e+04  6.48e+03  0.00e+00  1.00e+05
#    1   3.7110428e+04  -9.0758943e+04  1.46e+03  0.00e+00  2.25e+04
#    2   7.8386711e+03  -6.3002434e+04  2.22e+02  0.00e+00  3.42e+03
#    3   2.3126928e+03  -1.1535045e+04  6.60e+00  0.00e+00  1.02e+02
#    4   1.7274096e+03  -4.6828705e+02  9.92e-01  0.00e+00  1.53e+01
#    5   1.4427681e+03   5.0428637e+02  2.78e-01  0.00e+00  4.28e+00
#    6   1.2629142e+03   9.8545646e+02  6.78e-02  0.00e+00  1.05e+00
#    7   1.1800223e+03   1.0508977e+03  2.69e-02  0.00e+00  4.16e-01
#    8   1.1292457e+03   1.0894805e+03  2.26e-11  0.00e+00  6.43e-13
#    9   1.1096902e+03   1.1053332e+03  4.03e-11  0.00e+00  5.18e-13
#   10   1.1080977e+03   1.1070708e+03  5.92e-11  0.00e+00  3.02e-13
#   11   1.1075519e+03   1.1072839e+03  9.42e-11  0.00e+00  2.39e-13
#   12   1.1074099e+03   1.1073723e+03  2.43e-10  0.00e+00  6.69e-13
#   13   1.1073920e+03   1.1073861e+03  1.63e-09  0.00e+00  7.12e-13
#   14   1.1073904e+03   1.1073875e+03  2.80e-09  0.00e+00  5.44e-13
#   15   1.1073893e+03   1.1073886e+03  8.55e-09  0.00e+00  6.36e-13
#   16   1.1073890e+03   1.1073889e+03  1.28e-08  0.00e+00  5.01e-13
# Barrier time = 0.02 sec. (0.42 ticks)
#
# Total time on 32 threads = 0.02 sec. (0.42 ticks)
#
# Barrier - Optimal:  Objective =  1.1073889626e+03
# Solution time =    0.02 sec.  Iterations = 16
# Deterministic time = 0.42 ticks  (26.13 ticks/sec)
#
# CPLEX> Solution written to file 'C:\Users\hanbo\AppData\Local\Temp\tmpsbpu7wi4.cplex.sol'.
# CPLEX>
# Welcome to IBM(R) ILOG(R) CPLEX(R) Interactive Optimizer Community Edition 22.1.2.0
#   with Simplex, Mixed Integer & Barrier Optimizers
# 5725-A06 5725-A29 5724-Y48 5724-Y49 5724-Y54 5724-Y55 5655-Y21
# Copyright IBM Corp. 1988, 2024.  All Rights Reserved.
#
# Type 'help' for a list of available commands.
# Type 'help' followed by a command name for more
# information on commands.
#
# CPLEX> Logfile 'cplex.log' closed.
# Logfile 'C:\Users\hanbo\AppData\Local\Temp\tmpna9qsu0k.cplex.log' open.
# CPLEX> Problem 'C:\Users\hanbo\AppData\Local\Temp\tmp_qytk2jv.pyomo.lp' read.
# Read time = 0.00 sec. (0.01 ticks)
# CPLEX> Problem name         : C:\Users\hanbo\AppData\Local\Temp\tmp_qytk2jv.pyomo.lp
# Objective sense      : Minimize
# Variables            :      73  [Nneg: 68,  Free: 5,  Qobj: 6]
# Objective nonzeros   :      60
# Objective Q nonzeros :      16
# Linear constraints   :      49  [Less: 35,  Equal: 14]
#   Nonzeros           :     260
#   RHS nonzeros       :      31
#
# Variables            : Min LB: 0.000000         Max UB: all infinite
# Objective nonzeros   : Min   : 0.01000000       Max   : 1600.000
# Objective Q nonzeros : Min   : 220.0000         Max   : 1100.000
# Linear constraints   :
#   Nonzeros           : Min   : 1.000000         Max   : 1.000000
#   RHS nonzeros       : Min   : 4.000000         Max   : 200.0000
# CPLEX> Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# Number of nonzeros in lower triangle of Q = 5
# Using Approximate Minimum Degree ordering
# Total time for automatic ordering = 0.00 sec. (0.00 ticks)
# Summary statistics for factor of Q:
#   Rows in Factor            = 6
#   Integer space required    = 6
#   Total non-zeros in factor = 21
#   Total FP ops to factor    = 91
# Tried aggregator 1 time.
# QP Presolve eliminated 1 rows and 1 columns.
# QP Presolve added 0 rows and 6 columns.
# Aggregator did 9 substitutions.
# Reduced QP has 45 rows, 69 columns, and 289 nonzeros.
# Reduced QP objective Q matrix has 5 nonzeros.
# Presolve time = 0.00 sec. (0.05 ticks)
# Parallel mode: using up to 32 threads for barrier.
# Number of nonzeros in lower triangle of A*A' = 335
# Using Approximate Minimum Degree ordering
# Total time for automatic ordering = 0.00 sec. (0.02 ticks)
# Summary statistics for Cholesky factor:
#   Threads                   = 32
#   Rows in Factor            = 45
#   Integer space required    = 126
#   Total non-zeros in factor = 570
#   Total FP ops to factor    = 8970
#  Itn      Primal Obj        Dual Obj  Prim Inf Upper Inf  Dual Inf
#    0   1.3393062e+05  -1.3282326e+04  6.51e+03  0.00e+00  1.00e+05
#    1   3.7988981e+04  -8.5326163e+04  1.46e+03  0.00e+00  2.25e+04
#    2   8.5514461e+03  -6.0732664e+04  2.36e+02  0.00e+00  3.63e+03
#    3   2.3006237e+03  -1.2832457e+04  7.37e+00  0.00e+00  1.13e+02
#    4   1.7284549e+03  -1.8315182e+02  8.89e-01  0.00e+00  1.37e+01
#    5   1.4780818e+03   5.4119965e+02  2.87e-01  0.00e+00  4.42e+00
#    6   1.2756532e+03   1.0620357e+03  4.89e-02  0.00e+00  7.53e-01
#    7   1.1872008e+03   1.1013465e+03  1.35e-02  0.00e+00  2.08e-01
#    8   1.1627745e+03   1.1246121e+03  5.86e-03  0.00e+00  9.02e-02
#    9   1.1422557e+03   1.1372635e+03  6.96e-04  0.00e+00  1.07e-02
#   10   1.1401634e+03   1.1390466e+03  1.50e-04  0.00e+00  2.31e-03
#   11   1.1395968e+03   1.1393217e+03  3.58e-05  0.00e+00  5.51e-04
#   12   1.1394559e+03   1.1394247e+03  3.72e-06  0.00e+00  5.73e-05
#   13   1.1394414e+03   1.1394352e+03  7.11e-07  0.00e+00  1.09e-05
#   14   1.1394382e+03   1.1394374e+03  8.39e-08  0.00e+00  1.29e-06
#   15   1.1394377e+03   1.1394377e+03  8.60e-09  0.00e+00  2.82e-09
# Barrier time = 0.02 sec. (0.40 ticks)
#
# Total time on 32 threads = 0.02 sec. (0.40 ticks)
#
# Barrier - Optimal:  Objective =  1.1394377305e+03
# Solution time =    0.02 sec.  Iterations = 15
# Deterministic time = 0.40 ticks  (26.62 ticks/sec)
#
# CPLEX> Solution written to file 'C:\Users\hanbo\AppData\Local\Temp\tmpmphrrh80.cplex.sol'.
# CPLEX>
# Welcome to IBM(R) ILOG(R) CPLEX(R) Interactive Optimizer Community Edition 22.1.2.0
#   with Simplex, Mixed Integer & Barrier Optimizers
# 5725-A06 5725-A29 5724-Y48 5724-Y49 5724-Y54 5724-Y55 5655-Y21
# Copyright IBM Corp. 1988, 2024.  All Rights Reserved.
#
# Type 'help' for a list of available commands.
# Type 'help' followed by a command name for more
# information on commands.
#
# CPLEX> Logfile 'cplex.log' closed.
# Logfile 'C:\Users\hanbo\AppData\Local\Temp\tmp5tf86ffl.cplex.log' open.
# CPLEX> Problem 'C:\Users\hanbo\AppData\Local\Temp\tmp0rrtaxru.pyomo.lp' read.
# Read time = 0.00 sec. (0.01 ticks)
# CPLEX> Problem name         : C:\Users\hanbo\AppData\Local\Temp\tmp0rrtaxru.pyomo.lp
# Objective sense      : Minimize
# Variables            :      73  [Nneg: 68,  Free: 5,  Qobj: 6]
# Objective nonzeros   :      60
# Objective Q nonzeros :      16
# Linear constraints   :      49  [Less: 35,  Equal: 14]
#   Nonzeros           :     260
#   RHS nonzeros       :      31
#
# Variables            : Min LB: 0.000000         Max UB: all infinite
# Objective nonzeros   : Min   : 0.01000000       Max   : 1600.000
# Objective Q nonzeros : Min   : 220.0000         Max   : 1100.000
# Linear constraints   :
#   Nonzeros           : Min   : 1.000000         Max   : 1.000000
#   RHS nonzeros       : Min   : 6.000000         Max   : 200.0000
# CPLEX> Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# Number of nonzeros in lower triangle of Q = 5
# Using Approximate Minimum Degree ordering
# Total time for automatic ordering = 0.00 sec. (0.00 ticks)
# Summary statistics for factor of Q:
#   Rows in Factor            = 6
#   Integer space required    = 6
#   Total non-zeros in factor = 21
#   Total FP ops to factor    = 91
# Tried aggregator 1 time.
# QP Presolve eliminated 1 rows and 1 columns.
# QP Presolve added 0 rows and 6 columns.
# Aggregator did 9 substitutions.
# Reduced QP has 45 rows, 69 columns, and 289 nonzeros.
# Reduced QP objective Q matrix has 5 nonzeros.
# Presolve time = 0.00 sec. (0.05 ticks)
# Parallel mode: using up to 32 threads for barrier.
# Number of nonzeros in lower triangle of A*A' = 335
# Using Approximate Minimum Degree ordering
# Total time for automatic ordering = 0.00 sec. (0.02 ticks)
# Summary statistics for Cholesky factor:
#   Threads                   = 32
#   Rows in Factor            = 45
#   Integer space required    = 126
#   Total non-zeros in factor = 570
#   Total FP ops to factor    = 8970
#  Itn      Primal Obj        Dual Obj  Prim Inf Upper Inf  Dual Inf
#    0   1.3283190e+05  -1.2454379e+04  6.48e+03  0.00e+00  1.00e+05
#    1   3.6455212e+04  -9.4562384e+04  1.46e+03  0.00e+00  2.25e+04
#    2   6.7925026e+03  -6.3689364e+04  1.95e+02  0.00e+00  3.01e+03
#    3   2.4991934e+03  -1.2064877e+04  1.37e+01  0.00e+00  2.11e+02
#    4   1.7766330e+03  -1.1384019e+03  2.54e+00  0.00e+00  3.93e+01
#    5   1.3484974e+03   6.1462858e+02  3.12e-01  0.00e+00  4.82e+00
#    6   1.2136868e+03   8.5366063e+02  1.38e-01  0.00e+00  2.13e+00
#    7   1.1426220e+03   9.7190973e+02  5.11e-02  0.00e+00  7.89e-01
#    8   1.0862021e+03   1.0481118e+03  7.23e-03  0.00e+00  1.12e-01
#    9   1.0660333e+03   1.0608386e+03  8.81e-04  0.00e+00  1.36e-02
#   10   1.0643175e+03   1.0628600e+03  2.41e-04  0.00e+00  3.72e-03
#   11   1.0636351e+03   1.0632440e+03  6.27e-05  0.00e+00  9.67e-04
#   12   1.0634226e+03   1.0633700e+03  7.87e-06  0.00e+00  1.21e-04
#   13   1.0633972e+03   1.0633861e+03  1.60e-06  0.00e+00  2.46e-05
#   14   1.0633918e+03   1.0633899e+03  2.51e-07  0.00e+00  3.86e-06
#   15   1.0633912e+03   1.0633903e+03  1.21e-07  0.00e+00  1.79e-06
#   16   1.0633909e+03   1.0633907e+03  4.98e-08  0.00e+00  3.98e-07
#   17   1.0633908e+03   1.0633908e+03  1.13e-08  0.00e+00  4.96e-09
# Barrier time = 0.00 sec. (0.44 ticks)
#
# Total time on 32 threads = 0.00 sec. (0.44 ticks)
#
# Barrier - Optimal:  Objective =  1.0633907749e+03
# Solution time =    0.03 sec.  Iterations = 17
# Deterministic time = 0.44 ticks  (14.07 ticks/sec)
#
# CPLEX> Solution written to file 'C:\Users\hanbo\AppData\Local\Temp\tmpczmvg4ok.cplex.sol'.
# CPLEX>
# Welcome to IBM(R) ILOG(R) CPLEX(R) Interactive Optimizer Community Edition 22.1.2.0
#   with Simplex, Mixed Integer & Barrier Optimizers
# 5725-A06 5725-A29 5724-Y48 5724-Y49 5724-Y54 5724-Y55 5655-Y21
# Copyright IBM Corp. 1988, 2024.  All Rights Reserved.
#
# Type 'help' for a list of available commands.
# Type 'help' followed by a command name for more
# information on commands.
#
# CPLEX> Logfile 'cplex.log' closed.
# Logfile 'C:\Users\hanbo\AppData\Local\Temp\tmpyxmla7ed.cplex.log' open.
# CPLEX> Problem 'C:\Users\hanbo\AppData\Local\Temp\tmpsmrksjhk.pyomo.lp' read.
# Read time = 0.00 sec. (0.01 ticks)
# CPLEX> Problem name         : C:\Users\hanbo\AppData\Local\Temp\tmpsmrksjhk.pyomo.lp
# Objective sense      : Minimize
# Variables            :      73  [Nneg: 68,  Free: 5,  Qobj: 6]
# Objective nonzeros   :      60
# Objective Q nonzeros :      16
# Linear constraints   :      49  [Less: 35,  Equal: 14]
#   Nonzeros           :     260
#   RHS nonzeros       :      31
#
# Variables            : Min LB: 0.000000         Max UB: all infinite
# Objective nonzeros   : Min   : 0.01000000       Max   : 1600.000
# Objective Q nonzeros : Min   : 220.0000         Max   : 1100.000
# Linear constraints   :
#   Nonzeros           : Min   : 1.000000         Max   : 1.000000
#   RHS nonzeros       : Min   : 4.000000         Max   : 200.0000
# CPLEX> Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# Number of nonzeros in lower triangle of Q = 5
# Using Approximate Minimum Degree ordering
# Total time for automatic ordering = 0.00 sec. (0.00 ticks)
# Summary statistics for factor of Q:
#   Rows in Factor            = 6
#   Integer space required    = 6
#   Total non-zeros in factor = 21
#   Total FP ops to factor    = 91
# Tried aggregator 1 time.
# QP Presolve eliminated 1 rows and 1 columns.
# QP Presolve added 0 rows and 6 columns.
# Aggregator did 9 substitutions.
# Reduced QP has 45 rows, 69 columns, and 289 nonzeros.
# Reduced QP objective Q matrix has 5 nonzeros.
# Presolve time = 0.00 sec. (0.05 ticks)
# Parallel mode: using up to 32 threads for barrier.
# Number of nonzeros in lower triangle of A*A' = 335
# Using Approximate Minimum Degree ordering
# Total time for automatic ordering = 0.00 sec. (0.02 ticks)
# Summary statistics for Cholesky factor:
#   Threads                   = 32
#   Rows in Factor            = 45
#   Integer space required    = 126
#   Total non-zeros in factor = 570
#   Total FP ops to factor    = 8970
#  Itn      Primal Obj        Dual Obj  Prim Inf Upper Inf  Dual Inf
#    0   1.3393062e+05  -1.3282326e+04  6.51e+03  0.00e+00  1.00e+05
#    1   3.7008312e+04  -9.1206389e+04  1.46e+03  0.00e+00  2.25e+04
#    2   6.9153803e+03  -6.2200430e+04  1.94e+02  0.00e+00  2.99e+03
#    3   2.4686903e+03  -1.1887899e+04  1.24e+01  0.00e+00  1.91e+02
#    4   1.7783256e+03  -1.4518874e+03  2.55e+00  0.00e+00  3.92e+01
#    5   1.3504716e+03   6.7234786e+02  3.21e-01  0.00e+00  4.93e+00
#    6   1.2107254e+03   8.7871202e+02  1.39e-01  0.00e+00  2.14e+00
#    7   1.1430979e+03   9.7799276e+02  5.75e-02  0.00e+00  8.85e-01
#    8   1.0839799e+03   1.0496768e+03  6.76e-03  0.00e+00  1.04e-01
#    9   1.0659735e+03   1.0610341e+03  8.80e-04  0.00e+00  1.35e-02
#   10   1.0642836e+03   1.0629343e+03  2.34e-04  0.00e+00  3.60e-03
#   11   1.0636153e+03   1.0632838e+03  5.55e-05  0.00e+00  8.54e-04
#   12   1.0634518e+03   1.0633981e+03  8.50e-06  0.00e+00  1.31e-04
#   13   1.0634266e+03   1.0634143e+03  1.87e-06  0.00e+00  2.89e-05
#   14   1.0634207e+03   1.0634185e+03  3.11e-07  0.00e+00  4.78e-06
#   15   1.0634195e+03   1.0634194e+03  1.88e-08  0.00e+00  2.31e-07
#   16   1.0634194e+03   1.0634194e+03  3.86e-08  0.00e+00  6.17e-10
# Barrier time = 0.00 sec. (0.42 ticks)
#
# Total time on 32 threads = 0.00 sec. (0.42 ticks)
#
# Barrier - Optimal:  Objective =  1.0634194072e+03
# Solution time =    0.01 sec.  Iterations = 16
# Deterministic time = 0.42 ticks  (27.85 ticks/sec)
#
# CPLEX> Solution written to file 'C:\Users\hanbo\AppData\Local\Temp\tmph9qfufns.cplex.sol'.
# CPLEX>
# Welcome to IBM(R) ILOG(R) CPLEX(R) Interactive Optimizer Community Edition 22.1.2.0
#   with Simplex, Mixed Integer & Barrier Optimizers
# 5725-A06 5725-A29 5724-Y48 5724-Y49 5724-Y54 5724-Y55 5655-Y21
# Copyright IBM Corp. 1988, 2024.  All Rights Reserved.
#
# Type 'help' for a list of available commands.
# Type 'help' followed by a command name for more
# information on commands.
#
# CPLEX> Logfile 'cplex.log' closed.
# Logfile 'C:\Users\hanbo\AppData\Local\Temp\tmpwnj5fx3t.cplex.log' open.
# CPLEX> Problem 'C:\Users\hanbo\AppData\Local\Temp\tmp3xjmb7f1.pyomo.lp' read.
# Read time = 0.00 sec. (0.01 ticks)
# CPLEX> Problem name         : C:\Users\hanbo\AppData\Local\Temp\tmp3xjmb7f1.pyomo.lp
# Objective sense      : Minimize
# Variables            :      73  [Nneg: 68,  Free: 5,  Qobj: 6]
# Objective nonzeros   :      60
# Objective Q nonzeros :      16
# Linear constraints   :      49  [Less: 35,  Equal: 14]
#   Nonzeros           :     260
#   RHS nonzeros       :      27
#
# Variables            : Min LB: 0.000000         Max UB: all infinite
# Objective nonzeros   : Min   : 0.01000000       Max   : 1600.000
# Objective Q nonzeros : Min   : 220.0000         Max   : 1100.000
# Linear constraints   :
#   Nonzeros           : Min   : 1.000000         Max   : 1.000000
#   RHS nonzeros       : Min   : 1.000000         Max   : 200.0000
# CPLEX> Version identifier: 22.1.2.0 | 2024-12-09 | 8bd2200c8
# Number of nonzeros in lower triangle of Q = 5
# Using Approximate Minimum Degree ordering
# Total time for automatic ordering = 0.00 sec. (0.00 ticks)
# Summary statistics for factor of Q:
#   Rows in Factor            = 6
#   Integer space required    = 6
#   Total non-zeros in factor = 21
#   Total FP ops to factor    = 91
# Tried aggregator 1 time.
# QP Presolve eliminated 9 rows and 17 columns.
# QP Presolve added 0 rows and 6 columns.
# Aggregator did 11 substitutions.
# Reduced QP has 35 rows, 51 columns, and 237 nonzeros.
# Reduced QP objective Q matrix has 5 nonzeros.
# Presolve time = 0.00 sec. (0.06 ticks)
# Parallel mode: using up to 32 threads for barrier.
# Number of nonzeros in lower triangle of A*A' = 277
# Using Approximate Minimum Degree ordering
# Total time for automatic ordering = 0.00 sec. (0.02 ticks)
# Summary statistics for Cholesky factor:
#   Threads                   = 32
#   Rows in Factor            = 35
#   Integer space required    = 63
#   Total non-zeros in factor = 475
#   Total FP ops to factor    = 7907
#  Itn      Primal Obj        Dual Obj  Prim Inf Upper Inf  Dual Inf
#    0   1.3916998e+05  -3.7042435e+04  5.02e+03  9.60e+01  7.25e+04
#    1   3.8499015e+04  -8.1700678e+04  1.11e+03  2.12e+01  1.60e+04
#    2   6.2093968e+03  -3.8519139e+04  1.03e+02  1.97e+00  1.49e+03
#    3   2.2756466e+03  -3.3403335e+03  5.36e+00  1.02e-01  7.73e+01
#    4   1.5710456e+03   2.2038731e+02  8.06e-01  1.54e-02  1.16e+01
#    5   1.3646222e+03   1.2068167e+03  8.58e-02  1.64e-03  1.24e+00
#    6   1.3136270e+03   1.2748620e+03  1.24e-02  2.37e-04  1.79e-01
#    7   1.2927132e+03   1.2880179e+03  1.20e-03  2.30e-05  1.74e-02
#    8   1.2909561e+03   1.2896278e+03  3.28e-04  6.27e-06  4.73e-03
#    9   1.2902432e+03   1.2900799e+03  3.64e-05  6.95e-07  5.25e-04
#   10   1.2901686e+03   1.2901374e+03  6.55e-06  1.25e-07  9.44e-05
#   11   1.2901549e+03   1.2901516e+03  6.22e-07  1.19e-08  8.97e-06
#   12   1.2901534e+03   1.2901530e+03  6.76e-08  1.28e-09  9.66e-07
#   13   1.2901532e+03   1.2901532e+03  6.73e-09  3.81e-12  2.87e-09
# Barrier time = 0.00 sec. (0.33 ticks)
#
# Total time on 32 threads = 0.00 sec. (0.33 ticks)
#
# Barrier - Optimal:  Objective =  1.2901531850e+03
# Solution time =    0.00 sec.  Iterations = 13
# Deterministic time = 0.33 ticks  (329.22 ticks/sec)
#
# CPLEX> Solution written to file 'C:\Users\hanbo\AppData\Local\Temp\tmpi0unzazj.cplex.sol'.
# CPLEX>
